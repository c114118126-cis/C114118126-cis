# %% [markdown]
# # Mission 1：執行第一行 Python 程式

# %%
course_name = "Python與資料科學入門"
print("歡迎來到課程：", course_name)
# Out:
# 歡迎來到課程： Python與資料科學入門

# %% [markdown]
# # Mission 2：變數宣告與資料型態

# %%
student_count = 60
average_sleep_hours = 6.7
course_name = "Python與資料科學入門"
has_missing_value = True

print(type(student_count))
print(type(average_sleep_hours))
print(type(course_name))
print(type(has_missing_value))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
